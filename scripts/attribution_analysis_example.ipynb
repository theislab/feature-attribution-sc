# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from attribution_analysis import AttrAnalysis

# %%
attr_analysis = AttrAnalysis(data_path = './means-task2-tobe-exp.csv')
# Out:
# The loaded data has 2000 genes and 21 cell types

# %%
attr_analysis.get_attr_sign_count()
# Out:
#                         negative  zero postive
# Non-T/B cells                827   338     835
# Macrophages                  789   485     726
# Arterial EC                  704   544     752
# Smooth Muscle                880   201     919
# Neutrophilic                 925   330     745
# Bronchial Vessel 2           313  1390     297
# B cell lineage               787   504     709
# Bronchial Vessel 1           927   163     910
# AT2                          819   573     608
# Ciliated                     877   256     867
# T cell lineage               651   758     591
# Megakaryocytes               880   455     665
# KRT5- KRT17+ epithelial      736   442     822
# Mesothelium                  861   220     919
# Dendritic cells              678   533     789
# Submucosal Secretory         773   356     871
# AT1                          877   317     806
# Capillary                    707   383     910
# Rare                         857   236     907
# ...

# %%
attr_analysis.attr_sign_heat_map()

# %%
attr_analysis.get_attr_sum()
# Out:
#                   cell_type  negative_sum  positive_sum
# 0           Dendritic cells -1.963256e-09  1.499285e-09
# 1                 Capillary -1.784924e-08  1.484659e-08
# 2                    Venous -6.012267e-08  2.792914e-08
# 3   KRT5- KRT17+ epithelial -5.514547e-08  3.622035e-08
# 4                  Ciliated -1.584964e-07  1.150428e-07
# 5               Mesothelium -1.139762e-07  1.167221e-07
# 6             Non-T/B cells -5.423934e-07  3.834894e-07
# 7               Arterial EC -1.402996e-06  5.846522e-07
# 8                      Rare -1.117579e-06  8.672056e-07
# 9        Bronchial Vessel 1 -1.509275e-06  1.260184e-06
# 10            Smooth Muscle -4.404958e-06  4.164500e-06
# 11     Submucosal Secretory -6.984600e-05  6.010058e-05
# 12      Proliferating cells -1.241138e-03  3.011669e-03
# 13       Bronchial Vessel 2 -7.452774e-03  6.288063e-03
# 14           T cell lineage -9.953542e-03  1.809370e-02
# 15           B cell lineage -2.587262e-02  3.730393e-02
# ...

# %%
attr_analysis.attr_sum_barchart()

# %%
attr_analysis.get_highest_attr_genes()
# Out:
#    Non-T/B cells Macrophages Arterial EC Smooth Muscle Neutrophilic  \
# 0         RNASE1       SFTPB       CALCA        JCHAIN         AQP3
# 1         FCER1G       NAPSA        BTG2           VIM      TACSTD2
# 2         TYROBP      SFTPA2        SYT1        LGALS1        KRT19
# 3           KRT7       SFTPC       ASCL1          MZB1         KRT5
# 4         IFITM3       SFTA2        FOSB         CRIP1      ALDH3A1
# 5           CAV1        HOPX      HS3ST1         SFTPC       S100A2
# 6            VIM      SFTPA1        SCGN          LSP1         PERP
# 7         S100A4     SLC34A2        MEG3          SRGN          CLU
# 8        HLA-DRA    SERPINA1        BCAM      IGLV3-25       S100A8
# 9       HLA-DQA2      IFITM3        CHGA          SLPI     KIAA0101
# 10           CLU       PEBP4      NKX2-1      KIAA0125        FXYD3
# 11          ACP5      RNASE1        CHGB          EMP3        LYPD3
# 12         IL1RN      CLDN18       CLDN4         IGLC3        MGST1
# ...
